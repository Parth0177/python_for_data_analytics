# %% [markdown]
# ### STANDARD LIBRARY OVERVIEW
# Python's standard library overview is a vast collection of modules and packages that come bundled with python,providing a wide range of functionalities out of the box

# %%
import array
arr=array.array('i',[1,2,3,4,4,5,5,6])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 4, 5, 5, 6])

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import random
print(random.randint(91,100))
# Out:
# 92

# %%
print(random.choice(['apple','banana','cherry','grape','orange']))
# Out:
# banana

# %%
### file and directory access
import os
print(os.getcwd())
# Out:
# d:\CODING\Python udemy\modules and packages

# %%
os.mkdir('test2')

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# 'd:\\CODING\\Python udemy'

# %%
os.chdir('modules and packages')

# %%
os.getcwd()
# Out:
# 'd:\\CODING\\Python udemy\\modules and packages'

# %%
### High level operations on file and collection of files
import shutil
shutil.copyfile('source.txt','destination.txt') ### copying text from one to another file
# Out:
# 'destination.txt'

# %%
### Data Serialization
import json
data={"name":"John","age":30,}
json_string=json.dumps(data)
print(json_string)
print(type(json_string))

parsed_data=json.loads(json_string)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "John", "age": 30}
# <class 'str'>
# {'name': 'John', 'age': 30}
# <class 'dict'>

# %%
### CSV FILE

import csv
with open('example.csv','w',newline='') as file:
  writer=csv.writer(file)
  writer.writerow(['Name','Age','City'])
  writer.writerow(['John',30,'New York'])
  writer.writerow(['Jane',25,'Los Angeles'])
  writer.writerow(['Doe',22,'Chicago'])

with open('example.csv','r') as file:
  reader=csv.reader(file)
  for row in reader:
    print(row)
# Out:
# ['Name', 'Age', 'City']
# ['John', '30', 'New York']
# ['Jane', '25', 'Los Angeles']
# ['Doe', '22', 'Chicago']

# %%
### date time
from datetime import datetime, timedelta
now=datetime.now()
print(now)
# Out:
# 2026-03-23 00:39:00.459378

# %%
yesterday=now-timedelta(days=1899)
print(yesterday)
# Out:
# 2021-01-09 00:39:00.459378

# %%
import time
print(time.time())
time.sleep(5)
print("5 seconds have passed")
print(time.time())
# Out:
# 1774206686.2628264
# 5 seconds have passed
# 1774206691.2654524

# %%
### Regular Expressions
import re
pattern = r'\d+'
text='there are 3 cats and 4 dogs'
match=re.search(pattern,text)
print(match.group())
# Out:
# 3
