# %% [markdown]
# ### in python import modules and packages helps organize and reuse code

# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt,pi
print(sqrt(25))
print(sqrt(68))
print(pi)
# Out:
# 5.0
# 8.246211251235321
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import *

# %%
sqrt(45)
# Out:
# 6.708203932499369

# %%
print(pi)
# Out:
# 3.141592653589793

# %%
from packages.maths import addition
print(addition(5,10))
# Out:
# 15
